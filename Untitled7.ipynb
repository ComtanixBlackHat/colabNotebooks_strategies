# %%
import pandas as pd

# %%
 data = {
    'key': ['A', 'B', 'C', 'D', 'E', 'A', 'B', '6', 'D', 'E', 'A', 'B', '9', 'D', 'E'],
    'value': ['tag1', 'tag2', 'tag3', 'tag4', 'tag5', 'tag1', 'tag2', 'tag3', 'tag4', 'tag5', 'tag1', 'tag2', 'tag3', 'tag4', 'tag5'],

}

# %%
df = pd.DataFGrame(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-f0c2c5495c12> in <cell line: 1>()
# ----> 1 df = pd.Dataframe(data)
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
print(df["key"])
print(df["value"] == "tag")
