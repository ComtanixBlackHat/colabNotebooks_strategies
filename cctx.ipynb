# %%
# !pip install ccxt
# Out:
# Collecting ccxt
#   Downloading ccxt-4.3.61-py2.py3-none-any.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=60.9.0 in /usr/local/lib/python3.10/dist-packages (from ccxt) (67.7.2)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.10/dist-packages (from ccxt) (2024.7.4)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from ccxt) (2.31.0)
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.10/dist-packages (from ccxt) (42.0.8)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from ccxt) (4.12.2)
# Requirement already satisfied: aiohttp>=3.8 in /usr/local/lib/python3.10/dist-packages (from ccxt) (3.9.5)
# Collecting aiodns>=1.1.1 (from ccxt)
#   Downloading aiodns-3.2.0-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: yarl>=1.7.2 in /usr/local/lib/python3.10/dist-packages (from ccxt) (1.9.4)
# Collecting pycares>=4.0.0 (from aiodns>=1.1.1->ccxt)
#   Downloading pycares-4.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.7/288.7 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8->ccxt) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8->ccxt) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8->ccxt) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8->ccxt) (6.0.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8->ccxt) (4.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.6.1->ccxt) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->ccxt) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->ccxt) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->ccxt) (2.0.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt) (2.22)
# Installing collected packages: pycares, aiodns, ccxt
# Successfully installed aiodns-3.2.0 ccxt-4.3.61 pycares-4.4.0

# %%
import os
from pathlib import Path

import sys
import csv

# -----------------------------------------------------------------------------

# root = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(''))))
# sys.path.append(root + '/python')

import ccxt


# -----------------------------------------------------------------------------

def retry_fetch_ohlcv(exchange, max_retries, symbol, timeframe, since, limit):
    num_retries = 0
    try:
        num_retries += 1
        ohlcv = exchange.fetch_ohlcv(symbol, timeframe, since, limit)
        # print('Fetched', len(ohlcv), symbol, 'candles from', exchange.iso8601 (ohlcv[0][0]), 'to', exchange.iso8601 (ohlcv[-1][0]))
        return ohlcv
    except Exception:
        if num_retries > max_retries:
            raise  # Exception('Failed to fetch', timeframe, symbol, 'OHLCV in', max_retries, 'attempts')


def scrape_ohlcv(exchange, max_retries, symbol, timeframe, since, limit):
    earliest_timestamp = exchange.milliseconds()
    timeframe_duration_in_seconds = exchange.parse_timeframe(timeframe)
    timeframe_duration_in_ms = timeframe_duration_in_seconds * 1000
    timedelta = limit * timeframe_duration_in_ms
    all_ohlcv = []
    while True:
        fetch_since = earliest_timestamp - timedelta
        ohlcv = retry_fetch_ohlcv(exchange, max_retries, symbol, timeframe, fetch_since, limit)
        # if we have reached the beginning of history
        if ohlcv[0][0] >= earliest_timestamp:
            break
        earliest_timestamp = ohlcv[0][0]
        all_ohlcv = ohlcv + all_ohlcv
        print(len(all_ohlcv), symbol, 'candles in total from', exchange.iso8601(all_ohlcv[0][0]), 'to', exchange.iso8601(all_ohlcv[-1][0]))
        # if we have reached the checkpoint
        if fetch_since < since:
            break
    return all_ohlcv


def write_to_csv(filename, exchange, data):
    p = Path("./data/raw/", str(exchange))
    p.mkdir(parents=True, exist_ok=True)
    full_path = p / str(filename)
    with Path(full_path).open('w+', newline='') as output_file:
        csv_writer = csv.writer(output_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        csv_writer.writerows(data)


def scrape_candles_to_csv(filename, exchange_id, max_retries, symbol, timeframe, since, limit):
    # instantiate the exchange by id
    exchange = getattr(ccxt, exchange_id)({
        'enableRateLimit': True,  # required by the Manual
    })
    # convert since from string to milliseconds integer if needed
    if isinstance(since, str):
        since = exchange.parse8601(since)
    # preload all markets from the exchange
    exchange.load_markets()
    # fetch all candles
    ohlcv = scrape_ohlcv(exchange, max_retries, symbol, timeframe, since, limit)
    # save them to csv file
    # write_to_csv(filename, exchange, ohlcv)
    print('Saved', len(ohlcv), 'candles from', exchange.iso8601(ohlcv[0][0]), 'to', exchange.iso8601(ohlcv[-1][0]), 'to', filename)

# %%
scrape_candles_to_csv('btc_usdt_1m.csv', 'binance', 3, 'BTC/USDT', '1m', '2017-01-0100:00:00Z', 1000)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/ccxt/base/exchange.py in fetch(self, url, method, headers, body)
#     650             self.logger.debug("%s %s, Response: %s %s %s", method, url, http_status_code, headers, http_response)
# --> 651             response.raise_for_status()
#     652
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 451 Client Error:  for url: https://api.binance.com/api/v3/exchangeInfo
#
# During handling of the above exception, another exception occurred:
#
# ExchangeNotAvailable                      Traceback (most recent call last)
# <ipython-input-9-2bf506c9f470> in <cell line: 1>()
# ----> 1 scrape_candles_to_csv('btc_usdt_1m.csv', 'binance', 3, 'BTC/USDT', '1m', '2017-01-0100:00:00Z', 1000)
#
# <ipython-input-8-e2856c83e3d6> in scrape_candles_to_csv(filename, exchange_id, max_retries, symbol, timeframe, since, limit)
#      66         since = exchange.parse8601(since)
#      67     # preload all markets from the exchange
# ---> 68     exchange.load_markets()
#      69     # fetch all candles
#      70     ohlcv = scrape_ohlcv(exchange, max_retries, symbol, timeframe, since, limit)
#
# /usr/local/lib/python3.10/dist-packages/ccxt/base/exchange.py in load_markets(self, reload, params)
#    1538         if self.has['fetchCurrencies'] is True:
#    1539             currencies = self.fetch_currencies()
# -> 1540         markets = self.fetch_markets(params)
#    1541         return self.set_markets(markets, currencies)
#    1542
#
# /usr/local/lib/python3.10/dist-packages/ccxt/binance.py in fetch_markets(self, params)
#    2822             marketType = fetchMarkets[i]
#    2823             if marketType == 'spot':
# -> 2824                 promisesRaw.append(self.publicGetExchangeInfo(params))
#    2825             elif marketType == 'linear':
#    2826                 promisesRaw.append(self.fapiPublicGetExchangeInfo(params))
#
# /usr/local/lib/python3.10/dist-packages/ccxt/base/types.py in unbound_method(_self, params)
#      33
#      34         def unbound_method(_self, params={}):
# ---> 35             return _self.request(self.path, self.api, self.method, params, config=self.config)
#      36
#      37         self.unbound_method = unbound_method
#
# /usr/local/lib/python3.10/dist-packages/ccxt/binance.py in request(self, path, api, method, params, headers, body, config)
#   10506
#   10507     def request(self, path, api='public', method='GET', params={}, headers=None, body=None, config={}):
# > 10508         response = self.fetch2(path, api, method, params, headers, body, config)
#   10509         # a workaround for {"code":-2015,"msg":"Invalid API-key, IP, or permissions for action."}
#   10510         if api == 'private':
#
# /usr/local/lib/python3.10/dist-packages/ccxt/base/exchange.py in fetch2(self, path, api, method, params, headers, body, config)
#    3750                             self.sleep(retryDelay)
#    3751                         continue
# -> 3752                 raise e
#    3753         return None  # self line is never reached, but exists for c# value return requirement
#    3754
#
# /usr/local/lib/python3.10/dist-packages/ccxt/base/exchange.py in fetch2(self, path, api, method, params, headers, body, config)
#    3741         for i in range(0, retries + 1):
#    3742             try:
# -> 3743                 return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#    3744             except Exception as e:
#    3745                 if isinstance(e, NetworkError):
#
# /usr/local/lib/python3.10/dist-packages/ccxt/base/exchange.py in fetch(self, url, method, headers, body)
#     667             skip_further_error_handling = self.handle_errors(http_status_code, http_status_text, url, method, headers, http_response, json_response, request_headers, request_body)
#     668             if not skip_further_error_handling:
# --> 669                 self.handle_http_status_code(http_status_code, http_status_text, url, method, http_response)
#     670             raise ExchangeError(details) from e
#     671
#
# /usr/local/lib/python3.10/dist-packages/ccxt/base/exchange.py in handle_http_status_code(self, code, reason, url, method, body)
#    1716         if codeAsString in self.httpExceptions:
#    1717             ErrorClass = self.httpExceptions[codeAsString]
# -> 1718             raise ErrorClass(self.id + ' ' + method + ' ' + url + ' ' + codeAsString + ' ' + reason + ' ' + body)
#    1719
#    1720     @staticmethod
#
# ExchangeNotAvailable: binance GET https://api.binance.com/api/v3/exchangeInfo 451  {
#   "code": 0,
#   "msg": "Service unavailable from a restricted location according to 'b. Eligibility' in https://www.binance.com/en/terms. Please contact customer service if you believe you received this message in error."
# }
