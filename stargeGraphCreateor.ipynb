# %%
import warnings
import requests
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
symbols = ["BTC", "ETH"]
timeframe = "1h" #examples = 5m , 1d , 5h


exchanges = ["binance" , "okx" , "bybit" , "coinbase" , "cryptoCom" , "geminie" ]

# %%
def fetch_data(exchange):

    base_url = f"http://43.207.238.120:9000/api/graphApi"
    print(base_url)
    # print(parms)
    response = requests.get(base_url)
    print(response)
    # print(f"{exchange} = {response.json()}")
    if response.status_code != 200:
        print(response.json())
    response.raise_for_status()
    return response.json()

# %%
# for exchange in exchanges:
#   print(fetch_data(exchange))
print(fetch_data("exchange"))
# Out:
# http://43.207.238.120:9000/api/graphApi
# <Response [200]>
# ...
